# %%
# %matplotlib inline
from pandas import Series , DataFrame
import pandas as pd , numpy as np

import matplotlib.pyplot as plt

# %%
data = DataFrame(pd.read_csv('C://users/grlurton/documents/dhis_kenya/data_kenya.csv'))
data_categories = DataFrame(pd.read_csv('C://users/grlurton/documents/dhis_kenya/data_categories.csv'))
data_elements = DataFrame(pd.read_csv('C://users/grlurton/documents/dhis_kenya/data_elements.csv'))
org_units = DataFrame(pd.read_csv('C://users/grlurton/documents/dhis_kenya/org_units.csv'))
org_units_groups = DataFrame(pd.read_csv('C://users/grlurton/documents/dhis_kenya/org_units_groups.csv'))

# reports that organization units are supposed to make
org_units_report = DataFrame(pd.read_csv('C://users/grlurton/documents/dhis_kenya/org_units_data_sets.csv'))
print 'N of data values' , len(data)
# Out:
# N of data values 49809663

# %% [markdown]
# For simplicity, at this stage, we only select data from reports of form MOH.

# %%
reports_activity = ['oEfGJAQaARj' , 'GVGt4o7VkHk' , 'WtgleFiaJqO' , 'KbrFbt3w4bp', 
                    'b8k5cUrvVqr' , 'sfiNZ7atsK8','NLhjWzDVx4G','ovtKPo15xAg' , 'TXmr8u5rabj', 'DWKwKC6dnoB']

reports_conflicting = ['lPykYxJeLKM' , 'cvyzaRp8OlE'] #These reports have the same data elements so hard to make completeness vs 0

reports_hiv = ['kAofV66isvC' , 'yrYwif6R6sH' , 'GGgrU5QkjVs' , 'NJHaY8wlURg' , 'UeBJcYEoHeA' , 'IH4pYzRqTSE']

data_elements_list = data_elements[data_elements.datasets_ID.isin(reports_activity)]
data_elements_hiv = data_elements[data_elements.datasets_ID.isin(reports_hiv)]
data_weekly = data_elements[data_elements.datasets_ID == 'zJrL4HQqYmD']
print 'data keep :' , len(data_elements_list) , 'indicators ; data hiv :' , len(data_elements_hiv) , 'indicators'
print 'weekly data :' , len(data_weekly), 'indicators'
# Out:
# data keep : 794 indicators ; data hiv : 154 indicators
# weekly data : 29 indicators

# %%
data_moh = data[data.data_element_ID.isin(data_elements_list.data_element_ID)]
data_moh = data_moh[(data_moh['period'] != '2014AprilS1')]
data_moh = data_moh.drop(['Unnamed: 0' , 'last_update'] , axis = 1)
data_moh = data_moh[data_moh.data_element_ID != 'uxYaacfgY22'] # we don't care about the date the report was received


data_weekly = data[data.data_element_ID.isin(data_weekly.data_element_ID)]
data_weekly = data_weekly.drop(['Unnamed: 0' , 'last_update'] , axis = 1)

print len(data_moh)
print len(data_weekly)
# Out:
# 20710483
# 141343

# %% [markdown]
# # Measuring completeness

# %% [markdown]
# ## Making a full dataset

# %% [markdown]
# We first make a full dataset that includes explicitely all missing values. To do this we first put the data in wide format to create all the NA values. We then collapse select only reports due by each facility

# %%
#'oEfGJAQaARj'
reports_activity = ['GVGt4o7VkHk' , 'WtgleFiaJqO' , 'KbrFbt3w4bp', 'b8k5cUrvVqr' , 
                    'sfiNZ7atsK8','NLhjWzDVx4G','ovtKPo15xAg' , 'TXmr8u5rabj', 'DWKwKC6dnoB']

moh_elements = data_elements[data_elements.datasets_ID.isin(reports_activity)]

data_moh_merged = pd.merge(data_moh, moh_elements, left_on='data_element_ID', right_on='data_element_ID', 
                                     how='inner')

data_moh_merged.loc[((data_moh_merged.datasets_ID == 'GVGt4o7VkHk') & 
                            (data_moh_merged.category == 'lHl2rmXpHse')),'datasets_ID'] = 'oEfGJAQaARj'

data_moh_merged.loc[(data_moh_merged.datasets_ID == 'oEfGJAQaARj'),'datasets_name'] = "Outpatient summary < 5 years"

data_moh_merged = data_moh_merged.drop(['data_element_url' , 'datasets_name' , 'data_element_name','Unnamed: 0'] , axis = 1)

# %%
# First a very wide melt to get complete missing values in time
data_moh_wide = data_moh_merged.set_index(['datasets_ID',  
                                      'data_element_ID','category' ,'org_unit_ID', 'period']).unstack(['org_unit_ID','period'])

# %%
data_moh_wide.head()
# Out:
#                                               value                       \
# org_unit_ID                             bfiWYfkcaxW
# period                                       201205 201206 201404 201406
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ         NaN    NaN     33    NaN
#                             MJAGUpeHkpn         NaN    NaN     34    NaN
#             AIduSzrilaz     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ         NaN    NaN      7    NaN
#
#                                                                           \
# org_unit_ID                                           C1LIWUfN9s6
# period                                  201407 201411      201108 201301
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ    NaN     10         NaN     17
#                             MJAGUpeHkpn    NaN     10         NaN     23
#             AIduSzrilaz     Lt6CjodPpWZ    NaN    NaN         NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN    NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ    NaN      2         NaN    NaN
#
#                                                           ...                  \
# org_unit_ID                                               ...     I2LYLqKU6AW
# period                                  201308 201410     ...          201404
# datasets_ID data_element_ID category                      ...
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ     14    NaN     ...             NaN
#                             MJAGUpeHkpn     17    NaN     ...             NaN
#             AIduSzrilaz     Lt6CjodPpWZ    NaN    NaN     ...             NaN
#                             MJAGUpeHkpn    NaN    NaN     ...             NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ    NaN    NaN     ...             NaN
#
#                                                                         \
# org_unit_ID                                    Cx6s78Ev9QT vp0qwrZfnXZ
# period                                  201405      201001      201407
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ    NaN         NaN         NaN
#                             MJAGUpeHkpn    NaN         NaN         NaN
#             AIduSzrilaz     Lt6CjodPpWZ    NaN         NaN         NaN
#                             MJAGUpeHkpn    NaN         NaN         NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ    NaN         NaN         NaN
#
#                                                                              \
# org_unit_ID                             gIzaIg3BD9v fCInDXluNhx gIzaIg3BD9v
# period                                       201410      201407      201412
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ         NaN         NaN         NaN
#                             MJAGUpeHkpn         NaN         NaN         NaN
#             AIduSzrilaz     Lt6CjodPpWZ         NaN         NaN         NaN
#                             MJAGUpeHkpn         NaN         NaN         NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ         NaN         NaN         NaN
#
#
# org_unit_ID                                    MRsw0hX4BYh TfEDFytjC7A
# period                                  201407      201405      201412
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ    NaN         NaN         NaN
#                             MJAGUpeHkpn    NaN         NaN         NaN
#             AIduSzrilaz     Lt6CjodPpWZ    NaN         NaN         NaN
#                             MJAGUpeHkpn    NaN         NaN         NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ    NaN         NaN         NaN
#
# [5 rows x 359130 columns]

# %%
data_moh_wide2 = data_moh_wide.reindex()
#,'period',org_unit_ID'
#help(data_moh_wide.reindex)

# %%
data_moh_wide2.sortlevel(axis=0,inplace=True,sort_remaining=True)
data_moh_wide2.sortlevel(axis=1,inplace=True,sort_remaining=True)

# %%
print data_moh_wide2.loc[(report,slice(None),slice(None)),(slice(None) , slice(None) , slice(None))]
# Out:
#                                               value                       \
# org_unit_ID                             A01SoVxCOx3
# period                                       201201 201202 201203 201204
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
#             AIduSzrilaz     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
#             B7xc7C2bwmI     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             BKq0EhyLtyd     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
#             BMqY5dYHphX     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             Bd0iiac6bo5     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             BisljGQ6kvf     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             D0QBMSslDpI     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             ENjll6PbaI8     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
# ...                                             ...    ...    ...    ...
#             sgvaNvr1bSv     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             twpy25QKLk9     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
#             uYBa6RU8wUZ     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
#             ue73Z4usGVw     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             uiZFrHhwcMJ     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             vB6cPLkbDUX     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             vGdvTPt1JQV     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             xZkyYTbBimP     ELX9rT7wauT         NaN    NaN    NaN    NaN
#                             h9I08VnFouB         NaN    NaN    NaN    NaN
#                             jxQbojcxNi7         NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c         NaN    NaN    NaN    NaN
#             zels3jARvGQ     Lt6CjodPpWZ         NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn         NaN    NaN    NaN    NaN
#
#                                                                             \
# org_unit_ID
# period                                  201205 201206 201207 201208 201209
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             AIduSzrilaz     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             B7xc7C2bwmI     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             BKq0EhyLtyd     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             BMqY5dYHphX     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             Bd0iiac6bo5     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             BisljGQ6kvf     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             D0QBMSslDpI     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             ENjll6PbaI8     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
# ...                                        ...    ...    ...    ...    ...
#             sgvaNvr1bSv     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             twpy25QKLk9     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             uYBa6RU8wUZ     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             ue73Z4usGVw     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             uiZFrHhwcMJ     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             vB6cPLkbDUX     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             vGdvTPt1JQV     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             xZkyYTbBimP     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             zels3jARvGQ     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#
#                                                    ...                         \
# org_unit_ID                                        ...     zzN8bRK5K6x
# period                                  201210     ...          201404 201405
# datasets_ID data_element_ID category               ...
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ    NaN     ...             NaN    NaN
#                             MJAGUpeHkpn    NaN     ...             NaN    NaN
#             AIduSzrilaz     Lt6CjodPpWZ    NaN     ...             NaN    NaN
#                             MJAGUpeHkpn    NaN     ...             NaN    NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ    NaN     ...             NaN    NaN
#                             MJAGUpeHkpn    NaN     ...             NaN    NaN
#             B7xc7C2bwmI     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             BKq0EhyLtyd     Lt6CjodPpWZ    NaN     ...             NaN    NaN
#                             MJAGUpeHkpn    NaN     ...             NaN    NaN
#             BMqY5dYHphX     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             Bd0iiac6bo5     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             BisljGQ6kvf     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             D0QBMSslDpI     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             ENjll6PbaI8     Lt6CjodPpWZ    NaN     ...             NaN    NaN
#                             MJAGUpeHkpn    NaN     ...             NaN    NaN
# ...                                        ...     ...             ...    ...
#             sgvaNvr1bSv     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             twpy25QKLk9     Lt6CjodPpWZ    NaN     ...             NaN    NaN
#                             MJAGUpeHkpn    NaN     ...             NaN    NaN
#             uYBa6RU8wUZ     Lt6CjodPpWZ    NaN     ...             NaN    NaN
#                             MJAGUpeHkpn    NaN     ...             NaN    NaN
#             ue73Z4usGVw     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             uiZFrHhwcMJ     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             vB6cPLkbDUX     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             vGdvTPt1JQV     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             xZkyYTbBimP     ELX9rT7wauT    NaN     ...             NaN    NaN
#                             h9I08VnFouB    NaN     ...             NaN    NaN
#                             jxQbojcxNi7    NaN     ...             NaN    NaN
#                             zJz3wZ1KC6c    NaN     ...             NaN    NaN
#             zels3jARvGQ     Lt6CjodPpWZ    NaN     ...             NaN    NaN
#                             MJAGUpeHkpn    NaN     ...             NaN    NaN
#
#                                                                             \
# org_unit_ID
# period                                  201406 201407 201408 201409 201410
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             AIduSzrilaz     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             B7xc7C2bwmI     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             BKq0EhyLtyd     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             BMqY5dYHphX     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             Bd0iiac6bo5     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             BisljGQ6kvf     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             D0QBMSslDpI     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             ENjll6PbaI8     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
# ...                                        ...    ...    ...    ...    ...
#             sgvaNvr1bSv     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             twpy25QKLk9     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             uYBa6RU8wUZ     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#             ue73Z4usGVw     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             uiZFrHhwcMJ     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             vB6cPLkbDUX     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             vGdvTPt1JQV     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             xZkyYTbBimP     ELX9rT7wauT    NaN    NaN    NaN    NaN    NaN
#                             h9I08VnFouB    NaN    NaN    NaN    NaN    NaN
#                             jxQbojcxNi7    NaN    NaN    NaN    NaN    NaN
#                             zJz3wZ1KC6c    NaN    NaN    NaN    NaN    NaN
#             zels3jARvGQ     Lt6CjodPpWZ    NaN    NaN    NaN    NaN    NaN
#                             MJAGUpeHkpn    NaN    NaN    NaN    NaN    NaN
#
#
# org_unit_ID                                           zzjOSFPagVP
# period                                  201411 201412      201104
# datasets_ID data_element_ID category
# DWKwKC6dnoB A0iW2ssADiX     Lt6CjodPpWZ    NaN    NaN         NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN
#             AIduSzrilaz     Lt6CjodPpWZ    NaN    NaN         NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN
#             AYT1IPxFRZx     Lt6CjodPpWZ    NaN    NaN         NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN
#             B7xc7C2bwmI     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             BKq0EhyLtyd     Lt6CjodPpWZ    NaN    NaN         NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN
#             BMqY5dYHphX     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             Bd0iiac6bo5     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             BisljGQ6kvf     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             D0QBMSslDpI     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             ENjll6PbaI8     Lt6CjodPpWZ    NaN    NaN         NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN
# ...                                        ...    ...         ...
#             sgvaNvr1bSv     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             twpy25QKLk9     Lt6CjodPpWZ    NaN    NaN         NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN
#             uYBa6RU8wUZ     Lt6CjodPpWZ    NaN    NaN         NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN
#             ue73Z4usGVw     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             uiZFrHhwcMJ     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             vB6cPLkbDUX     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             vGdvTPt1JQV     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             xZkyYTbBimP     ELX9rT7wauT    NaN    NaN         NaN
#                             h9I08VnFouB    NaN    NaN         NaN
#                             jxQbojcxNi7    NaN    NaN         NaN
#                             zJz3wZ1KC6c    NaN    NaN         NaN
#             zels3jARvGQ     Lt6CjodPpWZ    NaN    NaN         NaN
#                             MJAGUpeHkpn    NaN    NaN         NaN
#
# [240 rows x 359130 columns]

# %%
# Functions to zeroify relevant mixing values

#idx = pd.IndexSlice
#nbr_na = []
#ncol = []

def how_much_null(data):
    out = sum(pd.isnull(data))
    return out

def zeroify(data):
    how_much = how_much_null(data)
    print data.head()
    total_length  = len(data)
    if how_much < total_length:
        data[pd.isnull(data)] = 0
    return data

# %%
df1 = pd.DataFrame(columns=['org_unit_ID', 'datasets_ID', 'data_element_ID', 'category','period','value'])

periods = data_moh['period'].unique()
dataSets = data_moh_wide.index.levels[0]

for report in dataSets:
    print '     Report' , report,  len(data_moh_wide.loc[report])
    moh_reindex_sub = data_moh_wide2.loc[(report,slice(None),slice(None)),(slice(None) , slice(None) , slice(None))]
    #dims = data_moh_wide[(data_moh_wide[report])][['datasets_ID','data_element_ID', 'category']]
    #data_try = moh_reindex_sub[periods]
    print "Let's Zeroify !!"
    data_try = moh_reindex_sub.apply(zeroify)
    data_try = pd.concat([data_try, dims], axis=1)
    df1 = df1.append(data_try)
# Out:
#      Report DWKwKC6dnoB 240
# Let's Zeroify !!
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201201), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201202), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201203), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201204), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201205), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201206), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201207), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201208), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201209), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201210), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201211), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201212), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201301), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201302), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201303), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201304), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201305), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201306), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201307), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201309), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201310), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201311), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201312), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201401), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201402), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201403), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201404), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201405), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201406), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201407), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201408), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201409), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201410), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201411), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A01SoVxCOx3, 201412), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201108), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201109), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201110), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201111), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201112), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201201), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201202), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201203), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201204), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201205), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201206), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201207), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201208), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201209), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201210), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201211), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201212), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201301), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201302), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201303), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201304), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201305), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201306), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201307), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201308), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201309), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201310), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201311), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201312), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201401), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201402), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201403), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201405), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201406), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201407), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201408), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201409), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201410), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201411), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A05h9ICwmHK, 201412), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201307), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201308), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201309), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201310), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201311), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201312), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201401), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201402), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201403), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201404), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201405), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201406), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0Ln8q092qB, 201407), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    10
#                               MJAGUpeHkpn    12
#              AIduSzrilaz      Lt6CjodPpWZ     0
#                               MJAGUpeHkpn     0
#              AYT1IPxFRZx      Lt6CjodPpWZ     0
# Name: (value, A0Ln8q092qB, 201408), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    16
#                               MJAGUpeHkpn    14
#              AIduSzrilaz      Lt6CjodPpWZ    13
#                               MJAGUpeHkpn     5
#              AYT1IPxFRZx      Lt6CjodPpWZ     7
# Name: (value, A0Ln8q092qB, 201409), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    23
#                               MJAGUpeHkpn    25
#              AIduSzrilaz      Lt6CjodPpWZ     1
#                               MJAGUpeHkpn     4
#              AYT1IPxFRZx      Lt6CjodPpWZ     3
# Name: (value, A0Ln8q092qB, 201410), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    25
#                               MJAGUpeHkpn    18
#              AIduSzrilaz      Lt6CjodPpWZ     0
#                               MJAGUpeHkpn     0
#              AYT1IPxFRZx      Lt6CjodPpWZ     5
# Name: (value, A0Ln8q092qB, 201411), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    17
#                               MJAGUpeHkpn    22
#              AIduSzrilaz      Lt6CjodPpWZ    10
#                               MJAGUpeHkpn     5
#              AYT1IPxFRZx      Lt6CjodPpWZ     2
# Name: (value, A0Ln8q092qB, 201412), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201201), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201202), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201203), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201204), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201205), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201206), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201207), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201208), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201209), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201210), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201211), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201212), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201301), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201302), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201303), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201304), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201305), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201306), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201307), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201308), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201309), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201310), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201311), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201312), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201401), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201402), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201403), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201405), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201407), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201408), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201409), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201410), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201411), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A0kUgKoBcbg, 201412), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201109), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201110), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201111), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201112), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201201), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201202), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201203), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201204), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201205), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201206), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201207), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201208), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201209), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201210), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, A14VKKcewbS, 201211), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
# ...
# Name: (value, Any5e34YGqV, 201301), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201302), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201303), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201304), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201305), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201306), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201307), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201308), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201309), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201310), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201311), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201312), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201401), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201402), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201403), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201404), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201405), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201406), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201407), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201408), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201409), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201410), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201411), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AIduSzrilaz      Lt6CjodPpWZ    0
#                               MJAGUpeHkpn    0
#              AYT1IPxFRZx      Lt6CjodPpWZ    0
# Name: (value, Any5e34YGqV, 201412), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201012), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201101), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201102), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201103), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201104), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201105), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201106), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201107), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201108), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201109), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201110), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201111), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201112), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201201), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201202), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201203), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201204), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201205), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201206), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201207), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201208), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201209), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201210), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201211), dtype: object
# datasets_ID  data_element_ID  category
# DWKwKC6dnoB  A0iW2ssADiX      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AIduSzrilaz      Lt6CjodPpWZ    NaN
#                               MJAGUpeHkpn    NaN
#              AYT1IPxFRZx      Lt6CjodPpWZ    NaN
# Name: (value, Ao618j1xAh9, 201212), dtype: object

# %%
# Functions to zeroify relevant mixing values

#idx = pd.IndexSlice
#nbr_na = []
#ncol = []

def how_much_null(data):
    out = sum(pd.isnull(data))
    return out

def zeroify(data):
    how_much = how_much_null(data)
    total_length  = len(data)
    if how_much < total_length:
        data[pd.isnull(data)] = 0
    return data

# %%
moh_reindex = data_moh_wide.loc[:,idx['value']].reset_index()

# %%
samp = range(0,10000)

# %%
moh_reindex2 = moh_reindex.loc[samp]

# %%
df1 = pd.DataFrame(columns=['org_unit_ID', 'datasets_ID', 'data_element_ID', 'category','period','value'])

# %%
n_orgunit = len(moh_reindex2['org_unit_ID'].unique() )
print n_orgunit
i = 1
b = 0

for org_unit in moh_reindex2['org_unit_ID'].unique() :
    print 'Unit' , org_unit
    a = 100 * i / n_orgunit
    if a > b :
        print a , '% done'
        b = a
    dataSets = moh_reindex2[moh_reindex2['org_unit_ID'] == org_unit]['datasets_ID'].unique()
    for report in dataSets:
        print '     Report' , report,  len(moh_reindex2[(moh_reindex2['org_unit_ID'] == org_unit) &
                                       (moh_reindex2['datasets_ID'] == report)])
        moh_reindex_sub = moh_reindex2[(moh_reindex2['org_unit_ID'] == org_unit) &
                                       (moh_reindex2['datasets_ID'] == report)][periods]
        dims = moh_reindex2[(moh_reindex2['org_unit_ID'] == org_unit) &
                                       (moh_reindex2['datasets_ID'] == report)][['org_unit_ID', 'datasets_ID', 
                                                                                 'data_element_ID', 'category']]
        aa =  np.repeat([range(len(dims))] ,2 , axis = 0 )
        print dims
        data_try = moh_reindex_sub[periods]
        data_try = data_try.apply(zeroify , axis = 0)
        #data_try = pd.concat([data_try.unstack(), dims], axis=1)
        df1 = df1.append(data_try)
    i = i + 1

# %%
df1.head()

# %%
print df1.stack()

# %%
data_moh_wide = df1.set_index(['org_unit_ID','datasets_ID',  
                                      'data_element_ID','category' ,periods])

# %%
wid = data_moh_wide.stack(dropna=False)

# %%
#data_full = df1
#data_full.columns = [' '.join(col).strip() for col in data_full.columns.values]
#data_full.columns = data_full.columns.str[6:29]

# Then we stack on org_unit_ID, so we have all period for all org_unit, including empty ones
#data_moh_full = data_moh_wide.stack(level=['org_unit_ID'] , dropna = False)

#print data_moh_wide.head()

# %%
#data_moh_wide_2 = data_moh_wide.stack(level=['org_unit_ID','data_element_ID'] , dropna = False)
#data_moh_wide_2.reset_index(inplace=True)

# %%
#data_moh_wide_2.reset_index(inplace=True)
#data_moh_wide_2.uniqueid = data_moh_wide_2["org_unit_ID"].str.cat(data_moh_wide_2['data_element_ID'], sep=' ' )
#ID = data_elements_requirement["org_unit_ID"].str.cat(data_elements_requirement['data_element_ID'], sep=' ' )

# %%
data_elements_requirement = pd.merge(org_units_report, df1 , left_on='dataset_ID', right_on='datasets_ID', 
                                     how='inner')

# %%
#col = data_moh_wide.columns
sec_data = data_moh_wide
#for fac in col.levels[1].tolist():
    #if not (fac in data_elements_requirement["org_unit_ID"].unique()) :
        #sec_data = sec_data.drop(level = fac , axis = 1)
        #print 'Dropped' , fac
        
        #indicators = data_elements_requirement[data_elements_requirement["org_unit_ID"] == fac]
        
        #indicators[]
        #print 'ah bah non !'

# %%
idx = pd.IndexSlice
#for fac in data_elements_requirement["org_unit_ID"].unique() :
#    if fac in col.levels[1] :
        #print data_moh_wide.loc[slice(None),(slice(None),fac,slice(None),slice(None))]

# %%
#data_moh_wide.loc[slice(None),(slice(None),'A05h9ICwmHK','BwROYFIiXKG','SeDaCnHi3m5')]

# %%
test = data_full.columns

test2 = test[test.isin(ID)].tolist()

print len(test2)

#print test2

data_ok = data_full[test2]

print len(data_full.columns)

#print data_full.head()

#print len(data_ok.columns) , 'm' , len(data_full.columns)

# %% [markdown]
# ## Describing missingness
#
# We first compute how much a orgunit should report on a monthly basis

# %%
def get_requirement_orgunit(data_element_list , report_requirement):
    """
    Function that takes a list of data elements and the reporting requirement of facilities and returns a merge data frame 
    representing a facility level requirement of different data elements
    """
    data_elements_requirement = pd.merge(report_requirement, data_element_list, left_on='dataset_ID', right_on='datasets_ID', 
                                     how='inner')
    data_elements_numbers = DataFrame(data_elements_requirement['org_unit_ID'].value_counts())
    data_elements_numbers.columns = ['required_data_elements']
    return data_elements_numbers

def get_requirement_data_element(data_element_list , report_requirement):
    """
    Function that takes a list of data elements and the reporting requirement of facilities and returns a merge data frame 
    representing a facility level requirement of different data elements
    """
    data_elements_requirement = pd.merge(report_requirement, data_element_list, left_on='dataset_ID', right_on='datasets_ID', 
                                     how='inner')
    data_elements_numbers = DataFrame(data_elements_requirement['data_element_ID'].value_counts())
    data_elements_numbers.columns = ['required_data_elements']
    return data_elements_numbers

# %% [markdown]
# Then compute how much orgunits actually report monthly

# %%
def get_availability_orgunit(data):
    """
    Function that reports the number of data elements available for each orgunit by period 
    """
    data_availability = pd.pivot_table(data , index=['org_unit_ID','period'] , aggfunc = len)['data_element_ID']
    return data_availability

def get_availability_data_element(data):
    """
    Function that reports the number of data elements available for each data_element by period 
    """
    data_availability = pd.pivot_table(data , index=['data_element_ID','period'] , aggfunc = len)['org_unit_ID']
    return data_availability

# %%
def get_completeness_orgunit(data , data_element_list , report_requirement):
    """
    Function that computes the data requirement and availability, and returns a description of completeness
    """
    required = get_requirement_orgunit(data_element_list , report_requirement)
    available = get_availability_orgunit(data)
    completeness = pd.merge(available.reset_index() , required.reset_index() , 
                            left_on = 'org_unit_ID' , right_on = 'index' ,
                            left_index=True, 
                            how='inner', sort=False)
    completeness['completeness'] = completeness['data_element_ID'] / completeness['required_data_elements']
    completeness = DataFrame(completeness)
    completeness = completeness[(completeness.completeness <= 1) & (completeness.period.astype(int) > 201012)]
    return completeness


def get_completeness_data_element(data , data_element_list , report_requirement):
    """
    Function that computes the data requirement and availability, and returns a description of completeness
    """
    required = get_requirement_data_element(data_element_list , report_requirement)
    print required.head()
    available = get_availability_data_element(data)
    completeness = pd.merge(available.reset_index() , required.reset_index() , 
                            left_on = 'data_element_ID' , right_on = 'index' ,
                            left_index=True, 
                            how='inner', sort=False)
    completeness['completeness'] = completeness['org_unit_ID'] / completeness['required_data_elements']
    
    completeness = DataFrame(completeness)
    completeness = completeness[(completeness.completeness <= 1) & (completeness.period.astype(int) > 201012)]
    return completeness

# %%
print 'Making completeness for OU'
data_completeness_fac = get_completeness_orgunit(data_moh , data_elements_list , org_units_report)
print 'Making completeness for DE'
data_completeness_de = get_completeness_data_element(data_moh , data_elements_list , org_units_report)

# %%
print data_completeness_de['required_data_elements'].value_counts()

# %%
data_completeness_de2 = data_completeness_de[data_completeness_de["required_data_elements"]  < 8970]
print 100*len(data_completeness_de2)  / len(data_completeness_de)

# %%
data_completeness_de2 = data_completeness_de[data_completeness_de["required_data_elements"]  < 7000]
data_completeness_de2 = data_completeness_de2.drop(['level_0' , 'org_unit_ID' , 'index' , 
                                                    'required_data_elements' ] , axis = 1)
#data_completeness_de2.reset_index(inplace=True) 
print len(data_completeness_de2)
print len(data_completeness_de)

# %%
df = data_completeness_de2.set_index(['period' , 'data_element_ID']).unstack(['data_element_ID']) 
print df.plot(legend = False , figsize = [15,10])

# %%
# How many values do we have ?
n_values_1 = len(data_moh_wide) - pd.isnull(data_moh_wide).sum(axis=0)
n_data_points = len(data_moh_wide)
print 'Maximum completeness for an indicator is' , (n_values_1 / n_data_points).max()
print 'Minimum completeness for an indicator is' , (n_values_1 / n_data_points).min()
print 'Mean completeness for an indicator is' , (n_values_1 / n_data_points).mean()
print 'Median completeness for an indicator is' , (n_values_1 / n_data_points).median()

# %% [markdown]
# CAVEAT : An unrlying hypothesis here is that every orgunit has to report on every data set every month. It is thus a raw UNDERESTIMATION of completeness

# %%
data_moh_wide = data_moh_wide.unstack(1)

n_values_2 = len(data_moh_wide) - pd.isnull(data_moh_wide).sum(axis=0)

n_periods = data_moh.period.nunique()
print 'Maximum completeness for an indicator serie for a facility is' , (n_values_2 / n_periods).max()
print 'Minimum completeness for an indicator  for a facility is' , (n_values_2 / n_periods).min()
print 'Mean completeness for an indicator  for a facility is' , (n_values_2 / n_periods).mean()
print 'Median completeness for an indicator  for a facility is' , (n_values_2 / n_periods).median()

# %% [markdown]
# ## Selection of Data

# %%
# Here, we only want to keep facilities with at least one serie with over 75% completness, and series with at least 
# 50%  overall completeness

completeness_fac = DataFrame(n_values_2 / n_periods > 0.75)
completeness_de = DataFrame(n_values_1 / n_data_points > 0.5)

completeness_fac.reset_index(inplace=True) 
completeness_de.reset_index(inplace=True) 

de_keep = completeness_de[completeness_de[0] > 0.5].data_element_ID.unique()
fac_keep = completeness_fac[completeness_fac[0] > 0.5].org_unit_ID.unique()
print 'We want to keep' , 100 * len(fac_keep) / len(completeness_fac.org_unit_ID.unique()) , '% of facilities'
print 'We want to keep' , 100 * len(de_keep) / len(completeness_de.data_element_ID.unique()) , '% of indicators'

# %%
data_comp = data_moh[data_moh['org_unit_ID'].isin(fac_keep) & data_moh['data_element_ID'].isin(de_keep)]
print 'We are keeping' , 100*len(data_comp) / len(data_moh) , '% of the data'

# %%
#### And rebuilding the missingness

# First a very wide melt to get complete missing values in time
data_comp_wide = data_comp.set_index(['org_unit_ID', 'period', 
                                      'category','data_element_ID']).unstack(['org_unit_ID'  ,'data_element_ID',
                                                                                 'category']) 

# Then we stack on org_unit_ID, so we have all period for all org_unit, including empty ones
data_comp_wide = data_comp_wide.stack(level=['org_unit_ID'] , dropna = False)



## We need to rename columns. not the simplest now
data_comp_wide.columns = [' '.join(col).strip() for col in data_comp_wide.columns.values]
data_comp_wide.reset_index(inplace=True)

# %% [markdown]
# ## AMELIA

# %%
# %load_ext rpy2.ipython

# %%
# %R rm(list = ls())

# %%
# %%R --input data_comp_wide
#
# save.image('//ihme.washington.edu/IHME/HOME/grlurton/imputation/python_export.RData')

# %% [raw]
# %%R --input data_comp_wide --output a_out
# library(Amelia)
#
# cols <- seq(2,ncol(data_comp_wide))
#
# data_comp_wide[,cols] = apply(data_comp_wide[,cols], 2, function(x) as.numeric(as.character(x)))
#
#
# a_out <- amelia(data_comp_wide , cs = "org_unit_ID" , ts = "period")

# %% [markdown]
# Ameliorer le travail R en exportant les donnees en Rdata, et reimportant les resultats.
#
# Faire tourner en parrallele

# %% [markdown]
# RAJOUTER LES COVARIABLES SITES. => sinon on a des observations completement missing
#
# en plus faire tourner d'abord sur le subset qui m'interesse et apres sur le reste

# %% [markdown]
# ## A venir

# %% [markdown]
# ARIMA / Kalman Filter

# %% [markdown]
# Make some mix

# %% [markdown]
# Catarina : amelia + arima : more or less similar
#
# arima est bon pour les facilites avec donnes partielles + statifie
# 	? code
#
# amelia : everything in one go : on annual data
# 	set threshold : si facility reports < 60 : set as missing.
# 	find most important covariate

# %% [markdown]
# Autres méthodes : MICE et Missforest
